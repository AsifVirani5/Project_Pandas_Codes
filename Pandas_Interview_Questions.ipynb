# %% [markdown]
# ### Import Pandas and Numpy Libraries

# %%
# Import pandas and numpy libraries

import pandas as pd
import numpy as np

# %% [markdown]
# ### Create a DataFrame from the stored Dictionary

# %%
cars_per_cap = [809, 731, 588, 18, 200, 70, 45]
country = ['United States', 'Australia', 'Japan', 'India', 'Russia', 'Morocco', 'Egypt']
drives_right = [True, False, False, False, True, True, True]

data = pd.DataFrame({"cars_per_cap" : cars_per_cap, "country": country , "drives_right":drives_right})

# %%
data
# Out:
#    cars_per_cap        country  drives_right
# 0           809  United States          True
# 1           731      Australia         False
# 2           588          Japan         False
# 3            18          India         False
# 4           200         Russia          True
# 5            70        Morocco          True
# 6            45          Egypt          True

# %% [markdown]
# ### Read a CSV file using pandas

# %%
cars_df = pd.read_csv("cars.csv") # Read the csv file   

cars_df
# Out:
#     USCA   US United States    809  FALSE
# 0  ASPAC  AUS     Australia  731.0   True
# 1  ASPAC  JAP         Japan  588.0   True
# 2  ASPAC   IN         India   18.0   True
# 3  ASPAC   RU        Russia  200.0  False
# 4  LATAM  MOR       Morocco   70.0  False
# 5    AFR   EG         Egypt   45.0  False
# 6    EUR  ENG       England    NaN   True

# %%
# Remove the header from the csv file by setting the header parameter to None

cars_df = pd.read_csv("cars.csv", header=None) # Read the csv file with header set to None     
cars_df
# Out:
#        0    1              2      3      4
# 0   USCA   US  United States  809.0  False
# 1  ASPAC  AUS      Australia  731.0   True
# 2  ASPAC  JAP          Japan  588.0   True
# 3  ASPAC   IN          India   18.0   True
# 4  ASPAC   RU         Russia  200.0  False
# 5  LATAM  MOR        Morocco   70.0  False
# 6    AFR   EG          Egypt   45.0  False
# 7    EUR  ENG        England    NaN   True

# %%
# assign the column names to the dataframe


cars_df.columns # Display the column names
# Out:
# Index([0, 1, 2, 3, 4], dtype='int64')

# %%
cars_df.columns = ['country code', 'region', 'country', 'cars_per_cap', 'drives_right'] # Assign the column names to the dataframe

# %%
cars_df.columns
# Out:
# Index(['country code', 'region', 'country', 'cars_per_cap', 'drives_right'], dtype='object')

# %%
cars_df
# Out:
#   country code region        country  cars_per_cap  drives_right
# 0         USCA     US  United States         809.0         False
# 1        ASPAC    AUS      Australia         731.0          True
# 2        ASPAC    JAP          Japan         588.0          True
# 3        ASPAC     IN          India          18.0          True
# 4        ASPAC     RU         Russia         200.0         False
# 5        LATAM    MOR        Morocco          70.0         False
# 6          AFR     EG          Egypt          45.0         False
# 7          EUR    ENG        England           NaN          True

# %% [markdown]
# ### Indexing of Columns in python pandas

# %%
cars_df.index # Display the index of the dataframe
# Out:
# RangeIndex(start=0, stop=8, step=1)

# %%
# Assign the country code as the index of the dataframe

cars_df = pd.read_csv("cars.csv", header=None, index_col=0) # Read the csv file with header set to None and index_col set to 0

# %%
cars_df
# Out:
#          1              2      3      4
# 0
# USCA    US  United States  809.0  False
# ASPAC  AUS      Australia  731.0   True
# ASPAC  JAP          Japan  588.0   True
# ASPAC   IN          India   18.0   True
# ASPAC   RU         Russia  200.0  False
# LATAM  MOR        Morocco   70.0  False
# AFR     EG          Egypt   45.0  False
# EUR    ENG        England    NaN   True

# %%
cars_df.columns = ['region', 'country', 'cars_per_cap', 'drives_right'] # Assign the column names to the dataframe

# %%
cars_df.index.name = 'country code' # Assign the index name to the dataframe

# %%
cars_df
# Out:
#              region        country  cars_per_cap  drives_right
# country code
# USCA             US  United States         809.0         False
# ASPAC           AUS      Australia         731.0          True
# ASPAC           JAP          Japan         588.0          True
# ASPAC            IN          India          18.0          True
# ASPAC            RU         Russia         200.0         False
# LATAM           MOR        Morocco          70.0         False
# AFR              EG          Egypt          45.0         False
# EUR             ENG        England           NaN          True

# %%
# remove the index name from the dataframe
cars_df.index.name = None # Remove the index name from the dataframe

# %%
cars_df
# Out:
#       region        country  cars_per_cap  drives_right
# USCA      US  United States         809.0         False
# ASPAC    AUS      Australia         731.0          True
# ASPAC    JAP          Japan         588.0          True
# ASPAC     IN          India          18.0          True
# ASPAC     RU         Russia         200.0         False
# LATAM    MOR        Morocco          70.0         False
# AFR       EG          Egypt          45.0         False
# EUR      ENG        England           NaN          True

# %%
# write the dataframe to a csv file
cars_df.to_csv("cars_new.csv") # Write the dataframe to a csv

# %%
new_df = pd.read_csv("cars_new.csv") # Read the csv file

# %%
new_df.columns
# Out:
# Index(['Unnamed: 0', 'region', 'country', 'cars_per_cap', 'drives_right'], dtype='object')

# %%
new_df.index.name = 'None'

# %%
new_df.columns = ['country code', 'region', 'country', 'cars_per_cap', 'drives_right']

# %%
new_df
# Out:
#      country code region        country  cars_per_cap  drives_right
# None
# 0            USCA     US  United States         809.0         False
# 1           ASPAC    AUS      Australia         731.0          True
# 2           ASPAC    JAP          Japan         588.0          True
# 3           ASPAC     IN          India          18.0          True
# 4           ASPAC     RU         Russia         200.0         False
# 5           LATAM    MOR        Morocco          70.0         False
# 6             AFR     EG          Egypt          45.0         False
# 7             EUR    ENG        England           NaN          True

# %%
new_df.index.delete = 'None'

# %%
new_df
# Out:
#      country code region        country  cars_per_cap  drives_right
# None
# 0            USCA     US  United States         809.0         False
# 1           ASPAC    AUS      Australia         731.0          True
# 2           ASPAC    JAP          Japan         588.0          True
# 3           ASPAC     IN          India          18.0          True
# 4           ASPAC     RU         Russia         200.0         False
# 5           LATAM    MOR        Morocco          70.0         False
# 6             AFR     EG          Egypt          45.0         False
# 7             EUR    ENG        England           NaN          True

# %%
# remove the index None from the dataframe
new_df = pd.read_csv("cars_new.csv", index_col=0) # Read the csv file with index_col set to 0

# %%
new_df
# Out:
#       region        country  cars_per_cap  drives_right
# USCA      US  United States         809.0         False
# ASPAC    AUS      Australia         731.0          True
# ASPAC    JAP          Japan         588.0          True
# ASPAC     IN          India          18.0          True
# ASPAC     RU         Russia         200.0         False
# LATAM    MOR        Morocco          70.0         False
# AFR       EG          Egypt          45.0         False
# EUR      ENG        England           NaN          True

# %%
df = pd.read_csv("https://media-doselect.s3.amazonaws.com/generic/A08MajL8qN4rq72EpVJbAP1Rw/marks_1.csv") # Read the csv file

# %%
df
# Out:
#      1|Akshay|Mathematics|50|40|80
# 0        2|Mahima|English|40|33|83
# 1     3|Vikas|Mathematics|50|42|84
# 2       4|Abhinav|English|40|31|78
# 3        5|Mahima|Science|50|40|80
# 4        6|Akshay|Science|50|49|98
# 5   7|Abhinav|Mathematics|50|47|94
# 6         8|Vikas|Science|50|40|80
# 7       9|Abhinav|Science|50|47|94
# 8        10|Vikas|English|40|39|98
# 9       11|Akshay|English|40|35|88
# 10  12|Mahima|Mathematics|50|43|86

# %%
df.columns
# Out:
# Index(['1|Akshay|Mathematics|50|40|80'], dtype='object')

# %%
# make the header as a row in the dataframe
df = pd.read_csv("https://media-doselect.s3.amazonaws.com/generic/A08MajL8qN4rq72EpVJbAP1Rw/marks_1.csv", header=None) # Read the csv file with header set to None

# %%
df
# Out:
#                                  0
# 0    1|Akshay|Mathematics|50|40|80
# 1        2|Mahima|English|40|33|83
# 2     3|Vikas|Mathematics|50|42|84
# 3       4|Abhinav|English|40|31|78
# 4        5|Mahima|Science|50|40|80
# 5        6|Akshay|Science|50|49|98
# 6   7|Abhinav|Mathematics|50|47|94
# 7         8|Vikas|Science|50|40|80
# 8       9|Abhinav|Science|50|47|94
# 9        10|Vikas|English|40|39|98
# 10      11|Akshay|English|40|35|88
# 11  12|Mahima|Mathematics|50|43|86

# %%
# Split the single column into multiple columns
df = df[0].str.split('|', expand=True) # Split the single column into multiple columns

# Assign new column names
df.columns = ["S.No", "Name", "Subject", "Maximum Marks", "Marks Obtained", "Percentage"]

# %%
df
# Out:
#    S.No     Name      Subject Maximum Marks Marks Obtained Percentage
# 0     1   Akshay  Mathematics            50             40         80
# 1     2   Mahima      English            40             33         83
# 2     3    Vikas  Mathematics            50             42         84
# 3     4  Abhinav      English            40             31         78
# 4     5   Mahima      Science            50             40         80
# 5     6   Akshay      Science            50             49         98
# 6     7  Abhinav  Mathematics            50             47         94
# 7     8    Vikas      Science            50             40         80
# 8     9  Abhinav      Science            50             47         94
# 9    10    Vikas      English            40             39         98
# 10   11   Akshay      English            40             35         88
# 11   12   Mahima  Mathematics            50             43         86

# %%
df
# Out:
#    S.No     Name      Subject Maximum Marks Marks Obtained Percentage
# 0     1   Akshay  Mathematics            50             40         80
# 1     2   Mahima      English            40             33         83
# 2     3    Vikas  Mathematics            50             42         84
# 3     4  Abhinav      English            40             31         78
# 4     5   Mahima      Science            50             40         80
# 5     6   Akshay      Science            50             49         98
# 6     7  Abhinav  Mathematics            50             47         94
# 7     8    Vikas      Science            50             40         80
# 8     9  Abhinav      Science            50             47         94
# 9    10    Vikas      English            40             39         98
# 10   11   Akshay      English            40             35         88
# 11   12   Mahima  Mathematics            50             43         86

# %%
df.index.name = "S.NO"

# %%
df
# Out:
#      S.No     Name      Subject Maximum Marks Marks Obtained Percentage
# S.NO
# 0       1   Akshay  Mathematics            50             40         80
# 1       2   Mahima      English            40             33         83
# 2       3    Vikas  Mathematics            50             42         84
# 3       4  Abhinav      English            40             31         78
# 4       5   Mahima      Science            50             40         80
# 5       6   Akshay      Science            50             49         98
# 6       7  Abhinav  Mathematics            50             47         94
# 7       8    Vikas      Science            50             40         80
# 8       9  Abhinav      Science            50             47         94
# 9      10    Vikas      English            40             39         98
# 10     11   Akshay      English            40             35         88
# 11     12   Mahima  Mathematics            50             43         86

# %%
#drop 1st column from the dataframe
df.drop("S.No", axis=1, inplace=True)# Drop the column from the dataframe

# %%
df
# Out:
#          Name      Subject Maximum Marks Marks Obtained Percentage
# S.NO
# 0      Akshay  Mathematics            50             40         80
# 1      Mahima      English            40             33         83
# 2       Vikas  Mathematics            50             42         84
# 3     Abhinav      English            40             31         78
# 4      Mahima      Science            50             40         80
# 5      Akshay      Science            50             49         98
# 6     Abhinav  Mathematics            50             47         94
# 7       Vikas      Science            50             40         80
# 8     Abhinav      Science            50             47         94
# 9       Vikas      English            40             39         98
# 10     Akshay      English            40             35         88
# 11     Mahima  Mathematics            50             43         86

# %% [markdown]
# ### Describing the data
# ## Case Study - Sales Data

# %%
import numpy as np
import pandas as pd
import matplotlib as plt    
import openpyxl as px

# %%
sales = pd.read_excel("sales.xlsx", index_col = [0,1]) # Read the excel file with index_col set to 0 and 1

# %%
sales
# Out:
#                                 No_of_Orders    Profit      Sales
# Market       Region
# Africa       Western Africa              251 -12901.51   78476.06
#              Southern Africa              85  11768.58   51319.50
#              North Africa                182  21643.08   86698.89
#              Eastern Africa              110   8013.04   44182.60
#              Central Africa              103  15606.30   61689.99
# Asia Pacific Western Asia                382 -16766.90  124312.24
#              Southern Asia               469  67998.76  351806.60
#              Southeastern Asia           533  20948.84  329751.38
#              Oceania                     646  54734.02  408002.98
#              Eastern Asia                414  72805.10  315390.77
#              Central Asia                 37  -2649.76    8190.74
# Europe       Western Europe              964  82091.27  656637.14
#              Southern Europe             338  18911.49  215703.93
# ...

# %%
# look into the top 3 rows
sales.head(3) # Display the top 3 rows
# Out:
#                         No_of_Orders    Profit     Sales
# Market Region
# Africa Western Africa            251 -12901.51  78476.06
#        Southern Africa            85  11768.58  51319.50
#        North Africa              182  21643.08  86698.89

# %%
# look into the last 3 rows 
sales.tail(3) # Display the last 3 rows
# Out:
#                    No_of_Orders    Profit      Sales
# Market Region
# USCA   Eastern US           443  47462.04  264973.98
#        Central US           356  33697.43  170416.31
#        Canada                49   7246.62   26298.81

# %%
# Display the information about the dataframe
sales.info() # Display the information about the dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 23 entries, ('Africa', 'Western Africa') to ('USCA', 'Canada')
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   No_of_Orders  23 non-null     int64
#  1   Profit        23 non-null     float64
#  2   Sales         23 non-null     float64
# dtypes: float64(2), int64(1)
# memory usage: 1.6+ KB

# %%
# Display the summary statistics of the dataframe

sales.describe() # Display the summary statistics of the dataframe
# Out:
#        No_of_Orders        Profit          Sales
# count     23.000000     23.000000      23.000000
# mean     366.478261  28859.944783  206285.108696
# std      246.590361  27701.193773  160589.886606
# min       37.000000 -16766.900000    8190.740000
# 25%      211.500000  12073.085000   82587.475000
# 50%      356.000000  20948.840000  170416.310000
# 75%      479.500000  45882.845000  290182.375000
# max      964.000000  82091.270000  656637.140000

# %%
# Boxplot profit and sales column 

sales[['Profit', 'Sales']].plot(kind='box', subplots= True) # Boxplot for Profit and Sales column
# Out:
# Profit       Axes(0.125,0.11;0.352273x0.77)
# Sales     Axes(0.547727,0.11;0.352273x0.77)
# dtype: object

# %%
df = pd.read_csv('https://cdn.upgrad.com/uploads/production/b3467ba4-4e13-44e9-8087-4d7e94cc7586/forestfires.csv')

# %%
print(df.describe())#Type your code for describing the dataset)
# Out:
#                 X           Y        FFMC         DMC          DC         ISI  \
# count  517.000000  517.000000  517.000000  517.000000  517.000000  517.000000
# mean     4.669246    4.299807   90.644681  110.872340  547.940039    9.021663
# std      2.313778    1.229900    5.520111   64.046482  248.066192    4.559477
# min      1.000000    2.000000   18.700000    1.100000    7.900000    0.000000
# 25%      3.000000    4.000000   90.200000   68.600000  437.700000    6.500000
# 50%      4.000000    4.000000   91.600000  108.300000  664.200000    8.400000
# 75%      7.000000    5.000000   92.900000  142.400000  713.900000   10.800000
# max      9.000000    9.000000   96.200000  291.300000  860.600000   56.100000
#
#              temp          RH        wind        rain         area
# count  517.000000  517.000000  517.000000  517.000000   517.000000
# mean    18.889168   44.288201    4.017602    0.021663    12.847292
# ...

# %%
print(df.columns)
# Out:
# Index(['X', 'Y', 'month', 'day', 'FFMC', 'DMC', 'DC', 'ISI', 'temp', 'RH',
#        'wind', 'rain', 'area'],
#       dtype='object')

# %%
print(df.shape)
# Out:
# (517, 13)

# %% [markdown]
# ### Python_Pandas_Indexing_Chunking_Conditions

# %%
# Read the excel file and set 2nd column as index

df = pd.read_excel("sales.xlsx", index_col = 1) # Read the excel file with index_col set to 1

# %%
df
# Out:
#                          Market  No_of_Orders    Profit      Sales
# Region
# Western Africa           Africa           251 -12901.51   78476.06
# Southern Africa          Africa            85  11768.58   51319.50
# North Africa             Africa           182  21643.08   86698.89
# Eastern Africa           Africa           110   8013.04   44182.60
# Central Africa           Africa           103  15606.30   61689.99
# Western Asia       Asia Pacific           382 -16766.90  124312.24
# Southern Asia      Asia Pacific           469  67998.76  351806.60
# Southeastern Asia  Asia Pacific           533  20948.84  329751.38
# Oceania            Asia Pacific           646  54734.02  408002.98
# Eastern Asia       Asia Pacific           414  72805.10  315390.77
# Central Asia       Asia Pacific            37  -2649.76    8190.74
# Western Europe           Europe           964  82091.27  656637.14
# Southern Europe          Europe           338  18911.49  215703.93
# ...

# %%
# Display sales columns
df["Sales"] # Display the Sales column using column name
# Out:
# Region
# Western Africa        78476.06
# Southern Africa       51319.50
# North Africa          86698.89
# Eastern Africa        44182.60
# Central Africa        61689.99
# Western Asia         124312.24
# Southern Asia        351806.60
# Southeastern Asia    329751.38
# Oceania              408002.98
# Eastern Asia         315390.77
# Central Asia           8190.74
# Western Europe       656637.14
# Southern Europe      215703.93
# Northern Europe      252969.09
# Eastern Europe       108258.93
# South America        210710.49
# Central America      461670.28
# Caribbean            116333.05
# Western US           251991.83
# Southern US          148771.91
# Eastern US           264973.98
# Central US           170416.31
# Canada                26298.81
# Name: Sales, dtype: float64

# %%
df.Sales # Display the Sales column using dot operator
# Out:
# Region
# Western Africa        78476.06
# Southern Africa       51319.50
# North Africa          86698.89
# Eastern Africa        44182.60
# Central Africa        61689.99
# Western Asia         124312.24
# Southern Asia        351806.60
# Southeastern Asia    329751.38
# Oceania              408002.98
# Eastern Asia         315390.77
# Central Asia           8190.74
# Western Europe       656637.14
# Southern Europe      215703.93
# Northern Europe      252969.09
# Eastern Europe       108258.93
# South America        210710.49
# Central America      461670.28
# Caribbean            116333.05
# Western US           251991.83
# Southern US          148771.91
# Eastern US           264973.98
# Central US           170416.31
# Canada                26298.81
# Name: Sales, dtype: float64

# %%
type(df["Sales"]) # Display the type of the column using column name
# Out:
# pandas.core.series.Series

# %%
df[["Profit", "Sales"]].head() # Display the Profit and Sales columns using column names under two square brackets the first square bracket is for the list of columns and the second square bracket is for the dataframe and the second square bracket is for the list of columns
# Out:
#                    Profit     Sales
# Region
# Western Africa  -12901.51  78476.06
# Southern Africa  11768.58  51319.50
# North Africa     21643.08  86698.89
# Eastern Africa    8013.04  44182.60
# Central Africa   15606.30  61689.99

# %%
 # Display the Southern Asia row using loc function
df.loc["Southern Asia", :] # Display the Southern Asia row using loc function
# Out:
# Market          Asia Pacific
# No_of_Orders             469
# Profit              67998.76
# Sales               351806.6
# Name: Southern Asia, dtype: object

# %%
df.loc["Southern Asia", "Sales"] # Display the Southern Asia row and Sales column using loc function
# Out:
# np.float64(351806.6)

# %%
df.iloc[6] # Display the 6th row using iloc function
# Out:
# Market          Asia Pacific
# No_of_Orders             469
# Profit              67998.76
# Sales               351806.6
# Name: Southern Asia, dtype: object

# %%
df.iloc[6, 3] # Display the 6th row and 3rd column using iloc function
# Out:
# np.float64(351806.6)

# %%
df.loc[:, ["Market", "Profit", "Sales"]] # Display the Market, Profit and Sales columns using loc function and ":" denotes all rows
# Out:
#                          Market    Profit      Sales
# Region
# Western Africa           Africa -12901.51   78476.06
# Southern Africa          Africa  11768.58   51319.50
# North Africa             Africa  21643.08   86698.89
# Eastern Africa           Africa   8013.04   44182.60
# Central Africa           Africa  15606.30   61689.99
# Western Asia       Asia Pacific -16766.90  124312.24
# Southern Asia      Asia Pacific  67998.76  351806.60
# Southeastern Asia  Asia Pacific  20948.84  329751.38
# Oceania            Asia Pacific  54734.02  408002.98
# Eastern Asia       Asia Pacific  72805.10  315390.77
# Central Asia       Asia Pacific  -2649.76    8190.74
# Western Europe           Europe  82091.27  656637.14
# Southern Europe          Europe  18911.49  215703.93
# Northern Europe          Europe  43237.44  252969.09
# Eastern Europe           Europe  25050.69  108258.93
# South America             LATAM  12377.59  210710.49
# Central America           LATAM  74679.54  461670.28
# ...

# %%
df.iloc[:, [0, 2, 3]] # Display the 1st, 2nd and 3rd columns using iloc function and ":" denotes all rows
# Out:
#                          Market    Profit      Sales
# Region
# Western Africa           Africa -12901.51   78476.06
# Southern Africa          Africa  11768.58   51319.50
# North Africa             Africa  21643.08   86698.89
# Eastern Africa           Africa   8013.04   44182.60
# Central Africa           Africa  15606.30   61689.99
# Western Asia       Asia Pacific -16766.90  124312.24
# Southern Asia      Asia Pacific  67998.76  351806.60
# Southeastern Asia  Asia Pacific  20948.84  329751.38
# Oceania            Asia Pacific  54734.02  408002.98
# Eastern Asia       Asia Pacific  72805.10  315390.77
# Central Asia       Asia Pacific  -2649.76    8190.74
# Western Europe           Europe  82091.27  656637.14
# Southern Europe          Europe  18911.49  215703.93
# Northern Europe          Europe  43237.44  252969.09
# Eastern Europe           Europe  25050.69  108258.93
# South America             LATAM  12377.59  210710.49
# Central America           LATAM  74679.54  461670.28
# ...

# %%
df.iloc[[0,2,3], :] # Display the 1st, 3rd and 4th rows using iloc function and ":" denotes all columns
# Out:
#                 Market  No_of_Orders    Profit     Sales
# Region
# Western Africa  Africa           251 -12901.51  78476.06
# North Africa    Africa           182  21643.08  86698.89
# Eastern Africa  Africa           110   8013.04  44182.60

# %%
df.loc[["Western Africa", "Southern Africa"], :] #  Display the Western Africa and Southern Africa rows using loc function and ":" denotes all columns
# Out:
#                  Market  No_of_Orders    Profit     Sales
# Region
# Western Africa   Africa           251 -12901.51  78476.06
# Southern Africa  Africa            85  11768.58  51319.50

# %%
df.loc[["Western Africa","Southern Africa"], ["Profit", "Sales"]] # Display the Western Africa and Southern Africa rows and Profit and Sales columns using loc function
# Out:
#                    Profit     Sales
# Region
# Western Africa  -12901.51  78476.06
# Southern Africa  11768.58  51319.50

# %%
df[df["Sales"]> 300000] # Display the rows where Sales is greater than 300000
# Out:
#                          Market  No_of_Orders    Profit      Sales
# Region
# Southern Asia      Asia Pacific           469  67998.76  351806.60
# Southeastern Asia  Asia Pacific           533  20948.84  329751.38
# Oceania            Asia Pacific           646  54734.02  408002.98
# Eastern Asia       Asia Pacific           414  72805.10  315390.77
# Western Europe           Europe           964  82091.27  656637.14
# Central America           LATAM           930  74679.54  461670.28

# %%
df[ (df["Market"].isin(["LATAM", "Europe"])) & (df["Sales"]> 250000) ] # Display the rows where Market is LATAM or Europe and Sales is greater than 250000
# Out:
#                  Market  No_of_Orders    Profit      Sales
# Region
# Western Europe   Europe           964  82091.27  656637.14
# Northern Europe  Europe           367  43237.44  252969.09
# Central America   LATAM           930  74679.54  461670.28

# %% [markdown]
# ##### Background
#
# An FMCG company P&J found that the sales of their best selling items are affected by the weather and rainfall trend. For example, the sale of tea increases when it rains, sunscreen is sold on the days when it is least likely to rain, and the sky is clear. They would like to check whether the weather patterns play a vital role in the sale of certain items. Hence as initial experimentation, they would like you to forecast the weather trend in the upcoming days. The target region for this activity is Australia; accordingly, this exercise will be based on analysing and cleaning the weather data from the Australian region available on public platforms.

# %%
import pandas as pd

# %%
# Read the dataframe
df = pd.read_csv("weatherdata.csv", header = 0) # Read the csv file with header set to 0
df.head(5)
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed
# 0           W           44.0
# 1         WNW           44.0
# 2         WSW           46.0
# 3          NE           24.0
# 4           W           41.0

# %%
# Find the days which had sunshine for more that 4 hours. These days will have increased sales of sunscreen.

df[df["Sunshine"] > 4] # Display the rows where Sunshine is greater than 4
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 5939    2009-01-01    Cobar     17.9     35.2       0.0         12.0
# 5940    2009-01-02    Cobar     18.4     28.9       0.0         14.8
# 5941    2009-01-03    Cobar     15.5     34.1       0.0         12.6
# 5942    2009-01-04    Cobar     19.4     37.6       0.0         10.8
# 5943    2009-01-05    Cobar     21.9     38.4       0.0         11.4
# ...            ...      ...      ...      ...       ...          ...
# 139108  2017-06-20   Darwin     19.3     33.4       0.0          6.0
# 139109  2017-06-21   Darwin     21.2     32.6       0.0          7.6
# 139110  2017-06-22   Darwin     20.7     32.8       0.0          5.6
# 139111  2017-06-23   Darwin     19.5     31.8       0.0          6.2
# 139112  2017-06-24   Darwin     20.2     31.7       0.0          5.6
#
#         Sunshine WindGustDir  WindGustSpeed
# 5939        12.3         SSW           48.0
# 5940        13.0           S           37.0
# ...

# %%
# The cold drink sales will most likely increase on the days which have high sunshine(>5) and high max temperature(>35). Use the filter operation to filter out these days

df[(df["Sunshine"] >5) & (df["MaxTemp"] > 35)] # Display the rows where Sunshine is greater than 5 and MaxTemp is greater than 35
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 5939    2009-01-01    Cobar     17.9     35.2       0.0         12.0
# 5942    2009-01-04    Cobar     19.4     37.6       0.0         10.8
# 5943    2009-01-05    Cobar     21.9     38.4       0.0         11.4
# 5944    2009-01-06    Cobar     24.2     41.0       0.0         11.2
# 5948    2009-01-10    Cobar     19.0     35.5       0.0         12.0
# ...            ...      ...      ...      ...       ...          ...
# 138862  2016-10-17   Darwin     25.1     35.2       0.0          7.4
# 138879  2016-11-03   Darwin     24.4     35.5       0.0          7.8
# 138892  2016-11-16   Darwin     25.7     35.2       0.0          5.4
# 138905  2016-11-29   Darwin     25.8     35.1       0.8          4.8
# 138910  2016-12-04   Darwin     25.8     35.2       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed
# 5939        12.3         SSW           48.0
# 5942        10.6         NNE           46.0
# ...

# %% [markdown]
# <h4 style = "color : Sky blue"> Example 2.1: Creating new columns</h4>
#
# If you noticed the filtering done in the earlier examples did not give precise information about the days, the data column simply has the dates. The date column can be split into the year, month and day of the month.
#
# **Special module of pandas** The "DatetimeIndex" is a particular module which has the capabilities to extract a day, month and year form the date.

# %%
# extract the year from the date column
df["year"] = pd.DatetimeIndex(df["Date"]).year # Extract the year

# %%
df.head(5)
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed  year
# 0           W           44.0  2008
# 1         WNW           44.0  2008
# 2         WSW           46.0  2008
# 3          NE           24.0  2008
# 4           W           41.0  2008

# %%
# Extract only the month from the date column
df["month"] = pd.DatetimeIndex(df["Date"]).month # Extract the month

# %%
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed  year  month
# 0           W           44.0  2008     12
# 1         WNW           44.0  2008     12
# 2         WSW           46.0  2008     12
# 3          NE           24.0  2008     12
# 4           W           41.0  2008     12

# %%
# Extract only the day from the date column
df["day"] = pd.DatetimeIndex(df["Date"]).day # Extract the day

# %%
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed  year  month  day
# 0           W           44.0  2008     12    1
# 1         WNW           44.0  2008     12    2
# 2         WSW           46.0  2008     12    3
# 3          NE           24.0  2008     12    4
# 4           W           41.0  2008     12    5

# %%
# Suppose you want to create a new column ‘is_raining’, which categorises days into rainy or not rainy days based on the amount of rainfall. You need to implement a function, which returns ‘Rainy’ if rainfall > 50 mm, and ‘Not raining’ otherwise. This can be done easily by using the apply() method on a column of the DataFrame

df["is_raining"]= df["Rainfall"].apply(lambda x: "Rainy" if x > 50 else "Not raining") # Apply the lambda function to the Rainfall column

# %%
df.head
# Out:
# <bound method NDFrame.head of               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 142188  2017-06-20    Uluru      3.5     21.8       0.0          NaN
# 142189  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 142190  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 142191  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 142192  2017-06-24    Uluru      7.8     27.0       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed  year  month  day   is_raining
# ...

# %%
# extract only the rainy days
df[df["is_raining"] == "Rainy"] # Display the rows where is_raining is Rainy
# Out:
#               Date   Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 429     2010-02-05     Albury     19.2     26.1      52.2          NaN
# 455     2010-03-08     Albury     18.1     25.5      66.0          NaN
# 690     2010-10-31     Albury     13.8     18.7      50.8          NaN
# 704     2010-11-14     Albury     19.2     22.6      52.6          NaN
# 787     2011-02-05     Albury     20.4     23.0      99.2          NaN
# ...            ...        ...      ...      ...       ...          ...
# 140532  2017-02-03  Katherine     23.4     33.0      62.0          NaN
# 140571  2017-03-14  Katherine     23.0     35.0      79.0         31.0
# 140578  2017-03-22  Katherine     24.1     34.5      61.4          NaN
# 142013  2016-12-26      Uluru     22.1     27.4      83.8          NaN
# 142014  2016-12-27      Uluru     22.1     35.8      63.8          NaN
#
#         Sunshine WindGustDir  WindGustSpeed  year  month  day is_raining
# ...

# %% [markdown]
# ### Employee Training
# Description
# You are provided with the dataset of a company which has offices across three cities - Mumbai, Bangalore and New Delhi. The dataset contains the rating (out of 5) of all the employees from different departments (Finance, HR, Marketing and Sales).
#
#
#
# The company has come up with a new policy that any individual with a rating equal to or below 3.5 needs to attend a training. Using dataframes, load the dataset and then derive the column ‘Training’ which shows ‘Yes’ for people who require training and ‘No’ for those who do not.

# %%
data = pd.read_csv("rating.csv", header = 0)

# %%
data.head(5)
# Out:
#       ID Department     Office  Rating
# 0  U2F26    Finance  New Delhi     3.4
# 1  U2M61  Marketing  New Delhi     3.9
# 2  U1S15      Sales  New Delhi     2.8
# 3  U1H87         HR     Mumbai     2.1
# 4  U1S51      Sales  New Delhi     4.6

# %%
data[data["Rating"]<3.5] # Display the rows where Rating is less than 3.5
# Out:
#         ID Department     Office  Rating
# 0    U2F26    Finance  New Delhi     3.4
# 2    U1S15      Sales  New Delhi     2.8
# 3    U1H87         HR     Mumbai     2.1
# 7    U3M44  Marketing  Bangalore     2.1
# 13   U1S75      Sales  Bangalore     3.0
# ..     ...        ...        ...     ...
# 527  U1S22      Sales  Bangalore     3.4
# 529  U2M11  Marketing  Bangalore     2.5
# 530  U3F53    Finance  Bangalore     3.2
# 531  U3S46      Sales  Bangalore     2.9
# 532  U3S28      Sales  New Delhi     2.9
#
# [245 rows x 4 columns]

# %%
data["Training"] = data["Rating"].apply(lambda x: "Yes" if x < 3.5 else "No") # Apply the lambda function to the Rating column

# %%
data
# Out:
#         ID Department     Office  Rating Training
# 0    U2F26    Finance  New Delhi     3.4      Yes
# 1    U2M61  Marketing  New Delhi     3.9       No
# 2    U1S15      Sales  New Delhi     2.8      Yes
# 3    U1H87         HR     Mumbai     2.1      Yes
# 4    U1S51      Sales  New Delhi     4.6       No
# ..     ...        ...        ...     ...      ...
# 528  U3S44      Sales  New Delhi     4.8       No
# 529  U2M11  Marketing  Bangalore     2.5      Yes
# 530  U3F53    Finance  Bangalore     3.2      Yes
# 531  U3S46      Sales  Bangalore     2.9      Yes
# 532  U3S28      Sales  New Delhi     2.9      Yes
#
# [533 rows x 5 columns]

# %%
data.head()
# Out:
#       ID Department     Office  Rating Training
# 0  U2F26    Finance  New Delhi     3.4      Yes
# 1  U2M61  Marketing  New Delhi     3.9       No
# 2  U1S15      Sales  New Delhi     2.8      Yes
# 3  U1H87         HR     Mumbai     2.1      Yes
# 4  U1S51      Sales  New Delhi     4.6       No

# %%
# In the dataframe created above, find the department that has the most efficient team (the team with minimum percentage of employees who need training).
data[data["Training"] == "No"].groupby("Department").size().idxmax() # Group by Department and find the department with minimum percentage of employees who need training
# Out:
# 'HR'

# %%
data.head()
# Out:
#       ID Department     Office  Rating Training
# 0  U2F26    Finance  New Delhi     3.4      Yes
# 1  U2M61  Marketing  New Delhi     3.9       No
# 2  U1S15      Sales  New Delhi     2.8      Yes
# 3  U1H87         HR     Mumbai     2.1      Yes
# 4  U1S51      Sales  New Delhi     4.6       No

# %% [markdown]
# <h4 style = "color : Sky blue"> Example 4.1: Grouping and Aggregate functions</h4>
#
# Find the location which received the most amount of rain in the given data. In this place, certain promotional offers can be put in place to boost sales of tea, umbrella etc.

# %%
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed  year  month  day   is_raining
# 0           W           44.0  2008     12    1  Not raining
# 1         WNW           44.0  2008     12    2  Not raining
# 2         WSW           46.0  2008     12    3  Not raining
# 3          NE           24.0  2008     12    4  Not raining
# 4           W           41.0  2008     12    5  Not raining

# %%
df.tail()
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 142188  2017-06-20    Uluru      3.5     21.8       0.0          NaN
# 142189  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 142190  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 142191  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 142192  2017-06-24    Uluru      7.8     27.0       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed  year  month  day   is_raining
# 142188       NaN           E           31.0  2017      6   20  Not raining
# 142189       NaN           E           31.0  2017      6   21  Not raining
# 142190       NaN         NNW           22.0  2017      6   22  Not raining
# 142191       NaN           N           37.0  2017      6   23  Not raining
# 142192       NaN          SE           28.0  2017      6   24  Not raining

# %%
# Find the coldest month in the dataset
df.groupby("month")["MinTemp"].mean().sort_values(ascending= True) # Group by month and find the coldest month
# Out:
# month
# 7      6.951308
# 8      7.465145
# 6      7.815031
# 9      9.460189
# 5      9.618572
# 10    11.531145
# 4     12.831979
# 11    14.299624
# 12    15.771514
# 3     15.904347
# 2     17.500239
# 1     17.520778
# Name: MinTemp, dtype: float64

# %%
# Find the coldest
df.groupby("Location")["Rainfall"].mean().sort_values(ascending= False) # Group by Location and find the location with maximum average rainfall
# Out:
# Location
# Cairns              5.765317
# Darwin              5.094048
# CoffsHarbour        5.054592
# GoldCoast           3.728933
# Wollongong          3.589127
# Williamtown         3.510985
# Townsville          3.488603
# NorahHead           3.382479
# Sydney              3.330231
# MountGinini         3.245241
# Brisbane            3.160536
# Newcastle           3.153022
# NorfolkIsland       3.137568
# Katherine           3.135599
# SydneyAirport       2.995335
# Witchcliffe         2.899658
# Walpole             2.877329
# Portland            2.531032
# Albany              2.255073
# BadgerysCreek       2.207925
# Tuggeranong         2.159040
# Richmond            2.152581
# Dartmoor            2.148554
# Penrith             2.135143
# MountGambier        2.087359
# Launceston          2.012219
# Albury              1.925710
# Perth               1.906295
# Watsonia            1.847692
# Melbourne           1.837772
# PerthAirport        1.761648
# ...

# %%
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed  year  month  day   is_raining
# 0           W           44.0  2008     12    1  Not raining
# 1         WNW           44.0  2008     12    2  Not raining
# 2         WSW           46.0  2008     12    3  Not raining
# 3          NE           24.0  2008     12    4  Not raining
# 4           W           41.0  2008     12    5  Not raining

# %%
# Group the dataframe 'df' by 'month' and 'day' and find the mean value for column 'rain' and 'wind
#df.groupby(["month", "day"]) # Group by month and day and find the mean value for rain and wind columns

df2 = df.groupby(["month", "day"])[["Rainfall", "WindGustSpeed"]].mean() # Group by month and day and find the mean value for rain and wind columns

#df.groupby("month", "day")["rain", "wind"].mean()

# %%
df2
# Out:
#            Rainfall  WindGustSpeed
# month day
# 1     1    1.827027      43.428571
#       2    2.040821      44.583333
#       3    1.635561      43.096692
#       4    2.277698      42.946701
#       5    1.720433      43.704082
# ...             ...            ...
# 12    27   4.346939      41.835404
#       28   3.733138      42.734375
#       29   1.802924      43.501558
#       30   2.203488      41.633028
#       31   2.273684      41.611801
#
# [366 rows x 2 columns]

# %%
df3 = pd.read_csv('https://cdn.upgrad.com/uploads/production/b3467ba4-4e13-44e9-8087-4d7e94cc7586/forestfires.csv')

# %%
df3.head()
# Out:
#    X  Y month  day  FFMC   DMC     DC  ISI  temp  RH  wind  rain  area
# 0  7  5   mar  fri  86.2  26.2   94.3  5.1   8.2  51   6.7   0.0   0.0
# 1  7  4   oct  tue  90.6  35.4  669.1  6.7  18.0  33   0.9   0.0   0.0
# 2  7  4   oct  sat  90.6  43.7  686.9  6.7  14.6  33   1.3   0.0   0.0
# 3  8  6   mar  fri  91.7  33.3   77.5  9.0   8.3  97   4.0   0.2   0.0
# 4  8  6   mar  sun  89.3  51.3  102.2  9.6  11.4  99   1.8   0.0   0.0

# %%
#Group the dataframe 'df' by 'month' and 'day' and find the mean value for column 'rain' and 'wind'.

df_1 = df3.groupby(["month", "day"])[["rain", "wind"]].mean()  # Group by month and day and find the mean value for rain and wind columns     
 
#Type your code to find the mean of columns 'rain' and 'wind'
print(df_1.head(20))
# Out:
#                rain      wind
# month day
# apr   fri  0.000000  3.100000
#       mon  0.000000  3.100000
#       sat  0.000000  4.500000
#       sun  0.000000  5.666667
#       thu  0.000000  5.800000
#       wed  0.000000  2.700000
# aug   fri  0.066667  4.766667
#       mon  0.000000  2.873333
#       sat  0.000000  4.310345
#       sun  0.025000  4.417500
#       thu  0.000000  3.503846
#       tue  0.300000  4.567857
#       wed  0.000000  3.520000
# dec   fri  0.000000  4.900000
#       mon  0.000000  8.500000
#       sun  0.000000  8.500000
#       thu  0.000000  4.900000
#       tue  0.000000  8.500000
#       wed  0.000000  8.000000
# feb   fri  0.000000  4.820000

# %% [markdown]
# <h4 style = "color : Sky blue"> Example 5.1: Merging Dataframes</h4>
#
# The join command is used to combine dataframes. Unlike hstack and vstack, the join command works by using a key to combine to dataframes.
#
# For example the total tea for the Newcastle store for the month of June 2011 is given in the file names ```junesales.csv``` Read in the data from the file and join it to the weather data exracted from the original dataframe.

# %%
# read the junesales dataframe
sales = pd.read_csv("junesales.csv", header = 0) # Read the csv file with header set to 0
sales.head()
# Out:
#        Date  Tea_sales(in 100's)
# 0  6/1/2011                   26
# 1  6/2/2011                   35
# 2  6/3/2011                   37
# 3  6/4/2011                   33
# 4  6/5/2011                   25

# %%
# Extract the month from the date column
sales ["day"]= pd.DatetimeIndex(sales["Date"]).day # Extract the month

# %%
sales.head()
# Out:
#        Date  Tea_sales(in 100's)  day
# 0  6/1/2011                   26    1
# 1  6/2/2011                   35    2
# 2  6/3/2011                   37    3
# 3  6/4/2011                   33    4
# 4  6/5/2011                   25    5

# %% [markdown]
# ### Filter the sales data for the relevant month and the appropriate location to a new dataframe.

# %%
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed  year  month  day   is_raining
# 0           W           44.0  2008     12    1  Not raining
# 1         WNW           44.0  2008     12    2  Not raining
# 2         WSW           46.0  2008     12    3  Not raining
# 3          NE           24.0  2008     12    4  Not raining
# 4           W           41.0  2008     12    5  Not raining

# %%
# Extract total tea for the Newcastle store for the month of June 2011

Newcastle_data = df[(df["Location"]== "Newcastle") & (df["month"]== 6) & (df["year"]== 2011)] # Filter the data for Newcastle store for the month of June 2011

# %%
Newcastle_data.head()
# Out:
#              Date   Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 15605  2011-06-01  Newcastle      NaN     21.2       6.0          NaN
# 15606  2011-06-02  Newcastle      NaN     20.2       4.0          NaN
# 15607  2011-06-03  Newcastle     10.7     20.2       0.4          NaN
# 15608  2011-06-04  Newcastle      9.4     20.4       0.0          NaN
# 15609  2011-06-05  Newcastle      9.6     18.8       3.0          NaN
#
#        Sunshine WindGustDir  WindGustSpeed  year  month  day   is_raining
# 15605       NaN         NaN            NaN  2011      6    1  Not raining
# 15606       NaN         NaN            NaN  2011      6    2  Not raining
# 15607       NaN         NaN            NaN  2011      6    3  Not raining
# 15608       NaN         NaN            NaN  2011      6    4  Not raining
# 15609       NaN         NaN            NaN  2011      6    5  Not raining

# %%
# Merge  the two dataframes on  the 'DayofMonth' column
merge_data = Newcastle_data.merge(sales, on = "day") # Merge the dataframes on the DayofMonth column)
merge_data.head()
# Out:
#        Date_x   Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2011-06-01  Newcastle      NaN     21.2       6.0          NaN       NaN
# 1  2011-06-02  Newcastle      NaN     20.2       4.0          NaN       NaN
# 2  2011-06-03  Newcastle     10.7     20.2       0.4          NaN       NaN
# 3  2011-06-04  Newcastle      9.4     20.4       0.0          NaN       NaN
# 4  2011-06-05  Newcastle      9.6     18.8       3.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed  year  month  day   is_raining    Date_y  \
# 0         NaN            NaN  2011      6    1  Not raining  6/1/2011
# 1         NaN            NaN  2011      6    2  Not raining  6/2/2011
# 2         NaN            NaN  2011      6    3  Not raining  6/3/2011
# 3         NaN            NaN  2011      6    4  Not raining  6/4/2011
# 4         NaN            NaN  2011      6    5  Not raining  6/5/2011
#
#    Tea_sales(in 100's)
# 0                   26
# 1                   35
# ...

# %%
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed  year  month  day   is_raining
# 0           W           44.0  2008     12    1  Not raining
# 1         WNW           44.0  2008     12    2  Not raining
# 2         WSW           46.0  2008     12    3  Not raining
# 3          NE           24.0  2008     12    4  Not raining
# 4           W           41.0  2008     12    5  Not raining

# %% [markdown]
# <h4 style = "color : Sky blue"> Example 5.2: Merging Dataframes</h4>
#
# ##### Types of joins.
#
# * INNER JOIN
# ![](1.png)
#
# * LEFT JOIN
# ![](2.png)
#
# * RIGHT JOIN
# ![](5.png)
#
# * FULL JOIN
# ![](4.png)
#
#
# Each state may have different tax laws, so we might want to add the states information to the data as well.
#
# The file ```locationsandstates.csv``` information about the states and location, the data in this file is **not** same as the weather data. It is possible that few locations in "data" (original dataframe) are not in this file, and all the locations in the file might not be in the original dataframe.
#
# In the original dataframe add the state data.

# %%
state = pd.read_csv("locationsandstates.csv", header = 0) # Read the csv file with header set to 0

# %%
state.head()
# Out:
#          Location             State
# 0          Sydney  New South Wales
# 1          Albury  New South Wales
# 2        Armidale  New South Wales
# 3        Bathurst  New South Wales
# 4  Blue Mountains  New South Wales

# %%
# merge the state data with the main data df dataframe on the 'Location' column
state_data = df.merge(state, on = "Location", how="left") # Merge the state data with the main data df dataframe on the Location column 
state_data.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed  year  month  day   is_raining             State
# 0           W           44.0  2008     12    1  Not raining  New South Wales
# 1         WNW           44.0  2008     12    2  Not raining  New South Wales
# 2         WSW           46.0  2008     12    3  Not raining  New South Wales
# 3          NE           24.0  2008     12    4  Not raining  New South Wales
# 4           W           41.0  2008     12    5  Not raining  New South Wales

# %%
df_11 = pd.read_csv('https://cdn.upgrad.com/uploads/production/1ed2840b-f083-44fe-9eb4-acda009ac620/restaurant-1.csv')
df_22 = pd.read_csv('https://cdn.upgrad.com/uploads/production/c87b99b4-467c-4128-8729-85bff0b0acbe/restaurant-2.csv')

# %%
df_11.head()
# Out:
#                         name                     address             city  \
# 0  arnie morton's of chicago   "435 s. la cienega blvd."    "los angeles"
# 1                 art's deli       "12224 ventura blvd."    "studio city"
# 2              bel-air hotel      "701 stone canyon rd."        "bel air"
# 3                 cafe bizou       "14016 ventura blvd."   "sherman oaks"
# 4                  campanile       "624 s. la brea ave."    "los angeles"
#
#             cuisine unique_id
# 0     "steakhouses"       '0'
# 1           "delis"       '1'
# 2     "californian"       '2'
# 3   "french bistro"       '3'
# 4     "californian"       '4'

# %%
df_22.head()
# Out:
#                       name_2                  address_2           city_2  \
# 0  arnie morton's of chicago   "435 s. la cienega blv."    "los angeles"
# 1         art's delicatessen      "12224 ventura blvd."    "studio city"
# 2              hotel bel-air     "701 stone canyon rd."        "bel air"
# 3                 cafe bizou      "14016 ventura blvd."   "sherman oaks"
# 4                  campanile      "624 s. la brea ave."    "los angeles"
#
#         cuisine_2 unique_id
# 0      "american"       '0'
# 1      "american"       '1'
# 2   "californian"       '2'
# 3        "french"       '3'
# 4      "american"       '4'

# %%
df_33 = df_11.merge(df_22, on = "unique_id", how = "inner") # Merge the dataframes on the Customer ID column

# %%
df_33
# Out:
#                                          name                     address  \
# 0                   arnie morton's of chicago   "435 s. la cienega blvd."
# 1                                  art's deli       "12224 ventura blvd."
# 2                               bel-air hotel      "701 stone canyon rd."
# 3                                  cafe bizou       "14016 ventura blvd."
# 4                                   campanile       "624 s. la brea ave."
# ..                                        ...                         ...
# 107                                    mifune             "1737 post st."
# 108                            plumpjack cafe         "3127 fillmore st."
# 109                                   postrio              "545 post st."
# 110  ritz-carlton dining room (san francisco)          "600 stockton st."
# 111                              rose pistola         "532 columbus ave."
#
#                  city            cuisine unique_id  \
# ...

# %%
df_33 = pd.read_csv('https://cdn.upgrad.com/uploads/production/1ed2840b-f083-44fe-9eb4-acda009ac620/restaurant-1.csv')
df_44 = pd.read_csv('https://cdn.upgrad.com/uploads/production/c87b99b4-467c-4128-8729-85bff0b0acbe/restaurant-2.csv')

# %%
df_33.head()
# Out:
#                         name                     address             city  \
# 0  arnie morton's of chicago   "435 s. la cienega blvd."    "los angeles"
# 1                 art's deli       "12224 ventura blvd."    "studio city"
# 2              bel-air hotel      "701 stone canyon rd."        "bel air"
# 3                 cafe bizou       "14016 ventura blvd."   "sherman oaks"
# 4                  campanile       "624 s. la brea ave."    "los angeles"
#
#             cuisine unique_id
# 0     "steakhouses"       '0'
# 1           "delis"       '1'
# 2     "californian"       '2'
# 3   "french bistro"       '3'
# 4     "californian"       '4'

# %%
df_44.head()
# Out:
#                       name_2                  address_2           city_2  \
# 0  arnie morton's of chicago   "435 s. la cienega blv."    "los angeles"
# 1         art's delicatessen      "12224 ventura blvd."    "studio city"
# 2              hotel bel-air     "701 stone canyon rd."        "bel air"
# 3                 cafe bizou      "14016 ventura blvd."   "sherman oaks"
# 4                  campanile      "624 s. la brea ave."    "los angeles"
#
#         cuisine_2 unique_id
# 0      "american"       '0'
# 1      "american"       '1'
# 2   "californian"       '2'
# 3        "french"       '3'
# 4      "american"       '4'

# %%
# Append two datasets df_33 and df_44, and print the combined dataframe.
df_65 = pd.concat([df_33, df_44], axis= 0) # Append the dataframes

# %%
df_65.head()
# Out:
#                         name                     address             city  \
# 0  arnie morton's of chicago   "435 s. la cienega blvd."    "los angeles"
# 1                 art's deli       "12224 ventura blvd."    "studio city"
# 2              bel-air hotel      "701 stone canyon rd."        "bel air"
# 3                 cafe bizou       "14016 ventura blvd."   "sherman oaks"
# 4                  campanile       "624 s. la brea ave."    "los angeles"
#
#             cuisine unique_id name_2 address_2 city_2 cuisine_2
# 0     "steakhouses"       '0'    NaN       NaN    NaN       NaN
# 1           "delis"       '1'    NaN       NaN    NaN       NaN
# 2     "californian"       '2'    NaN       NaN    NaN       NaN
# 3   "french bistro"       '3'    NaN       NaN    NaN       NaN
# 4     "californian"       '4'    NaN       NaN    NaN       NaN

# %%
gold = pd.DataFrame({'Country': ['USA', 'France', 'Russia'],
                         'Medals': [15, 13, 9]}
                    )
silver = pd.DataFrame({'Country': ['USA', 'Germany', 'Russia'],
                        'Medals': [29, 20, 16]}
                    )
bronze = pd.DataFrame({'Country': ['France', 'USA', 'UK'],
                        'Medals': [40, 28, 27]}
                    )

gold.head()
# Out:
#   Country  Medals
# 0     USA      15
# 1  France      13
# 2  Russia       9

# %%
silver.head()
# Out:
#    Country  Medals
# 0      USA      29
# 1  Germany      20
# 2   Russia      16

# %%
bronze.head()
# Out:
#   Country  Medals
# 0  France      40
# 1     USA      28
# 2      UK      27

# %%
Medal_tally = pd.concat([gold, silver, bronze], axis=0) # Append the dataframes

# %%
Medal_tally
# Out:
#    Country  Medals
# 0      USA      15
# 1   France      13
# 2   Russia       9
# 0      USA      29
# 1  Germany      20
# 2   Russia      16
# 0   France      40
# 1      USA      28
# 2       UK      27

# %%
Medal_tally.groupby("Country")["Medals"].sum().sort_values(ascending= False) # Group by Country and find the sum of Medals
# Out:
# Country
# USA        72
# France     53
# UK         27
# Russia     25
# Germany    20
# Name: Medals, dtype: int64

# %% [markdown]
# ### A pivot table is quite a useful tool to represent a DataFrame in a structured and simplified manner. It acts as an alternative to the groupby() function in Pandas. Pivot tables provide excel-like functionalities to create aggregate tables.

# %%
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed  year  month  day   is_raining
# 0           W           44.0  2008     12    1  Not raining
# 1         WNW           44.0  2008     12    2  Not raining
# 2         WSW           46.0  2008     12    3  Not raining
# 3          NE           24.0  2008     12    4  Not raining
# 4           W           41.0  2008     12    5  Not raining

# %%
Average_Rainfall = df.pivot_table(index = "Location", columns = "month", values = "Rainfall", aggfunc = "mean")

# %%
Average_Rainfall.head()
# Out:
# month                1         2         3         4         5         6   \
# Location
# Adelaide       0.772593  0.883784  1.213636  1.434335  2.252632  2.234646
# Albany         0.887636  0.692825  1.156296  2.066379  2.546909  3.923166
# Albury         1.475269  2.372222  2.156134  2.000833  1.616727  1.975665
# AliceSprings   2.093478  1.860177  0.843728  0.695359  0.506859  0.174242
# BadgerysCreek  2.697744  2.970233  3.590441  2.774684  1.441860  3.102381
#
# month                7         8         9         10        11        12
# Location
# Adelaide       2.944275  2.476494  1.755642  0.915472  0.741221  1.217167
# Albany         3.839113  3.775403  3.594167  1.982258  1.462343  1.076987
# Albury         2.256452  2.239837  2.148472  1.495833  2.193333  1.314634
# AliceSprings   0.718548  0.196774  0.451667  0.349194  0.795833  1.785124
# BadgerysCreek  1.009756  1.372532  1.132203  1.386498  2.596507  2.292857

# %%
Average_Rainfall = df.pivot_table(index = "Location", columns = "month", values = "Sunshine", aggfunc = "mean")

# %%
Average_Rainfall.head()
# Out:
# month                1          2         3         4         5         6   \
# Location
# Adelaide      11.126347   9.665942  8.222286  7.357576  5.323932  4.789286
# Albany         8.521491   7.492308  6.338819  5.898947  5.454545  5.146154
# AliceSprings   9.996522  10.392308  9.434167  9.229000  8.528365  8.388384
# Brisbane       8.219549   8.841063  7.322794  7.702532  7.537500  6.211969
# Cairns         6.729388   6.362944  6.538589  7.285859  7.118894  7.353333
#
# month               7          8          9          10         11        12
# Location
# Adelaide      4.774468   5.903759   6.783217   8.536806   9.046939  9.489262
# Albany        5.184793   5.955760   6.698558   7.250000   7.979904  7.932161
# AliceSprings  8.773148  10.278469  10.171569  10.436275  10.013462  9.355769
# Brisbane      7.243956   8.691727   8.676580   9.192000   9.322642  8.094167
# Cairns        7.225926   8.699537   9.031746   8.833962   8.311058  7.754460

# %% [markdown]
# ### Pandas Codes Link : https://pandas.pydata.org/pandas-docs/version/0.15/tutorials.html
